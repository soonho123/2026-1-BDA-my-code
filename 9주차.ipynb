# %% [markdown]
# <a href="https://colab.research.google.com/github/soonho123/2026-1-BDA-my-code/blob/main/9%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Korean font for matplotlib
# !apt-get update -qq
# !apt-get install fonts-nanum -qq > /dev/null

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
fm.fontManager.addfont(fontpath)
plt.rc('font', family='NanumBarunGothic')

# For minus signs
plt.rcParams['axes.unicode_minus'] = False
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !pip install pydataset

# %%
from pydataset import data
tg = data('ToothGrowth')
tg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 1 to 60
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   len     60 non-null     float64
#  1   supp    60 non-null     object
#  2   dose    60 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.9+ KB

# %%
tg.head()
# Out:
#     len supp  dose
# 1   4.2   VC   0.5
# 2  11.5   VC   0.5
# 3   7.3   VC   0.5
# 4   5.8   VC   0.5
# 5   6.4   VC   0.5

# %%
tg.tail()
# Out:
#      len supp  dose
# 56  30.9   OJ   2.0
# 57  26.4   OJ   2.0
# 58  27.3   OJ   2.0
# 59  29.4   OJ   2.0
# 60  23.0   OJ   2.0

# %%
tg.supp.value_counts()
# Out:
# supp
# VC    30
# OJ    30
# Name: count, dtype: int64

# %%
tg.dose.value_counts()
# Out:
# dose
# 0.5    20
# 1.0    20
# 2.0    20
# Name: count, dtype: int64

# %%
tg.describe()
# Out:
#              len       dose
# count  60.000000  60.000000
# mean   18.813333   1.166667
# std     7.649315   0.628872
# min     4.200000   0.500000
# 25%    13.075000   0.500000
# 50%    19.250000   1.000000
# 75%    25.275000   2.000000
# max    33.900000   2.000000

# %%
from numpy._core.defchararray import center
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data=tg, x='dose', y='len', hue='supp', dodge = 'True')
plt.title('기니피그 치아 성장')
plt.xlabel('치아 길이')
plt.ylabel('용량')
plt.legend(title = 'Supplement', loc = 'best')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(data=tg, x='dose', y='len', hue='supp', dodge = 'True')
plt.title('기니피그 치아 성장')
plt.xlabel('치아 길이')
plt.ylabel('용량')
plt.legend(title = 'Supplement')
plt.tight_layout()
plt.show()

# %%
plt.plot([1,2,3,4], [5,6,7,8], ls='', marker='.')
plt.show()

# %%
mtc = data('mtcars')
mtc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Mazda RX4 to Volvo 142E
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 3.0+ KB

# %%
mtc.head()
# Out:
#                     mpg  cyl   disp   hp  drat  ...   qsec  vs  am  gear  carb
# Mazda RX4          21.0    6  160.0  110  3.90  ...  16.46   0   1     4     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  ...  17.02   0   1     4     4
# Datsun 710         22.8    4  108.0   93  3.85  ...  18.61   1   1     4     1
# Hornet 4 Drive     21.4    6  258.0  110  3.08  ...  19.44   1   0     3     1
# Hornet Sportabout  18.7    8  360.0  175  3.15  ...  17.02   0   0     3     2
#
# [5 rows x 11 columns]

# %%
import seaborn as sns
ax = sns.countplot(data = mtc, x = 'gear',
                   order = mtc.gear.value_counts().index)
for p in ax.patches:
  height = p.get_height()
  ax.text(x = (p.get_x() + p.get_width() / 2.) , y = (height + .3),
          s = int(height), ha = 'center', size = 10, color = 'red')
  ax.set_ylim(0,17)
  plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=lcs, x = 'dpi', y = 'sr', hue = 'pop15', palette = 'viridis',
                 size = 'pop75' , sizes = (20,200))
plt.title('저축율과 소득, 나이 구조비교')
plt.xlabel('dpi')
plt.ylabel('sr')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15399/129299882.py in <cell line: 0>()
#       1 plt.figure(figsize=(5,5))
# ----> 2 sns.scatterplot(data=lcs, x = 'dpi', y = 'sr', hue = 'pop15', palette = 'viridis',
#       3                  size = 'pop75' , sizes = (20,200))
#       4 plt.title('저축율과 소득, 나이 구조비교')
#       5 plt.xlabel('dpi')
#
# NameError: name 'lcs' is not defined

# %%
plt.hist(mtc.mpg)
plt.show()

# %%
plt.hist(mtc.mpg)
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtc.mpg, rwidth=7, edgecolor = 'yellow',)
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtc.mpg, rwidth=7, edgecolor = 'white',)
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtc.wt, bins=[1.5, 4.5, 5.5, 5.6], density = True , edgecolor = 'white')
# Out:
# (array([0.30208333, 0.09375   , 0.        ]),
#  array([1.5, 4.5, 5.5, 5.6]),
#  <BarContainer object of 3 artists>)

# %%
from pydataset import data
iris = data('iris')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
n, bins, patches = plt.hist(iris['Sepal.Length'], bins = 20,
                            color = 'yellowgreen', edgecolor = 'white')
print(n)
print(bins)
print(patches)
# Out:
# [ 4.  5.  7. 16.  9.  5. 13. 14. 10.  6. 10. 16.  7. 11.  4.  2.  4.  1.
#   5.  1.]
# [4.3  4.48 4.66 4.84 5.02 5.2  5.38 5.56 5.74 5.92 6.1  6.28 6.46 6.64
#  6.82 7.   7.18 7.36 7.54 7.72 7.9 ]
# <BarContainer object of 20 artists>

# %%
n
# Out:
# array([ 4.,  5.,  7., 16.,  9.,  5., 13., 14., 10.,  6., 10., 16.,  7.,
#        11.,  4.,  2.,  4.,  1.,  5.,  1.])

# %%
bins
# Out:
# array([4.3 , 4.48, 4.66, 4.84, 5.02, 5.2 , 5.38, 5.56, 5.74, 5.92, 6.1 ,
#        6.28, 6.46, 6.64, 6.82, 7.  , 7.18, 7.36, 7.54, 7.72, 7.9 ])

# %%
patches
# Out:
# <BarContainer object of 20 artists>

# %%
plt.cm.viridis

# %%
n[0]
# Out:
# np.float64(4.0)

# %%
max(n)
# Out:
# np.float64(16.0)

# %%
n[1]/max(n)
# Out:
# np.float64(0.3125)

# %%
n, bins, patches = plt.hist(iris['Sepal.Length'], bins = 20,
                            color = 'yellowgreen', edgecolor = 'white')
for i in range(len(patches)):
  patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))
plt.show()
