# %% [markdown]
# <a href="https://colab.research.google.com/github/soonho123/2026-1-BDA-my-code/blob/main/%EC%B2%AB%EC%88%98%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01주차 데이터  시각화 준비와 기초

# %% [markdown]
# ## 간단한 데이터 시각화
# - matplotlib 활영 데이터 시각화
# - 한글 처리

# %%
import sys
sys. version
# Out:
# '3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]'

# %%
import site
site. getsitepackages()
# Out:
# ['/usr/local/lib/python3.12/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.12/dist-packages']

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'

# %%
import matplotlib as mpl

mpl.__version__
# Out:
# '3.10.0'

# %%
# %config inlinBackend.figure_format = 'retina'

# %%
import koreanize_matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_803/1721685219.py in <cell line: 0>()
# ----> 1 import koreanize_matplotlib
#
# ModuleNotFoundError: No module named 'koreanize_matplotlib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import matplotlib. pyplot as plt
plt.title('데이터 시각화 한글 준비와 기본 직선 그래프')
plt.plot ([10, 5, 20, 30])
plt.show()

# %%
pip install koreanize_matplotlib
# Out:
# Collecting koreanize_matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from koreanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.17.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 26.0 MB/s eta 0:00:00
# Installing collected packages: koreanize_matplotlib
# Successfully installed koreanize_matplotlib-0.1.1

# %%
import koreanize_matplotlib

# %%
import pandas as pd
pop = pd.read_csv('pop.csv', encoding='cp949', index_col=0, thousands='.')
pop
# Out:
#                       2026년02월_총인구수 2026년02월_세대수  2026년02월_세대당 인구  \
# 행정구역
# 전국  (1000000000)         51,106,229   24,350,797              210
# 서울특별시  (1100000000)       9,304,129    4,512,818              206
# 부산광역시  (2600000000)       3,239,016    1,576,653              205
# 대구광역시  (2700000000)       2,351,461    1,115,161              211
# 인천광역시  (2800000000)       3,054,367    1,404,284              218
# 광주광역시  (2900000000)       1,389,235      659,087              211
# 대전광역시  (3000000000)       1,441,405      699,675              206
# 울산광역시  (3100000000)       1,089,835      499,950              218
# 세종특별자치시  (3600000000)       391,240      165,449              236
# 경기도  (4100000000)        13,742,072    6,138,755              224
# 강원특별자치도  (5100000000)     1,506,699      769,508              196
# 충청북도  (4300000000)        1,596,816      799,712              200
# 충청남도  (4400000000)        2,136,064    1,064,222              201
# 전북특별자치도  (5200000000)     1,721,941      869,571              198
# 전라남도  (4600000000)        1,776,547      913,568              194
# 경상북도  (4700000000)        2,500,499    1,295,998              193
# 경상남도  (4800000000)        3,201,389    1,550,713              206
# 제주특별자치도  (5000000000)       663,514      315,673              210
#
#                       2026년02월_남자 인구수 2026년02월_여자 인구수  2026년02월_남여 비율
# 행정구역
# 전국  (1000000000)           25,429,357      25,676,872              99
# 서울특별시  (1100000000)         4,482,300       4,821,829              93
# 부산광역시  (2600000000)         1,574,040       1,664,976              95
# 대구광역시  (2700000000)         1,151,654       1,199,807              96
# 인천광역시  (2800000000)         1,525,266       1,529,101             100
# 광주광역시  (2900000000)           685,321         703,914              97
# 대전광역시  (3000000000)           718,084         723,321              99
# 울산광역시  (3100000000)           561,965         527,870             106
# 세종특별자치시  (3600000000)         194,784         196,456              99
# 경기도  (4100000000)           6,899,712       6,842,360             101
# 강원특별자치도  (5100000000)         757,648         749,051             101
# 충청북도  (4300000000)            813,918         782,898             104
# 충청남도  (4400000000)          1,097,210       1,038,854             106
# 전북특별자치도  (5200000000)         858,094         863,847              99
# 전라남도  (4600000000)            897,622         878,925             102
# 경상북도  (4700000000)          1,265,562       1,234,937             102
# 경상남도  (4800000000)          1,614,651       1,586,738             102
# 제주특별자치도  (5000000000)         331,526         331,988             100

# %%
pop. columns[2]
# Out:
# '2026년02월_세대당 인구'

# %%
pop.index
# Out:
# Index(['전국  (1000000000)', '서울특별시  (1100000000)', '부산광역시  (2600000000)',
#        '대구광역시  (2700000000)', '인천광역시  (2800000000)', '광주광역시  (2900000000)',
#        '대전광역시  (3000000000)', '울산광역시  (3100000000)', '세종특별자치시  (3600000000)',
#        '경기도  (4100000000)', '강원특별자치도  (5100000000)', '충청북도  (4300000000)',
#        '충청남도  (4400000000)', '전북특별자치도  (5200000000)', '전라남도  (4600000000)',
#        '경상북도  (4700000000)', '경상남도  (4800000000)', '제주특별자치도  (5000000000)'],
#       dtype='object', name='행정구역')

# %%
pop.index[4]
# Out:
# '인천광역시  (2800000000)'

# %%
for i in  range(len(pop)):
  print(pop.index[i])
# Out:
# 전국  (1000000000)
# 서울특별시  (1100000000)
# 부산광역시  (2600000000)
# 대구광역시  (2700000000)
# 인천광역시  (2800000000)
# 광주광역시  (2900000000)
# 대전광역시  (3000000000)
# 울산광역시  (3100000000)
# 세종특별자치시  (3600000000)
# 경기도  (4100000000)
# 강원특별자치도  (5100000000)
# 충청북도  (4300000000)
# 충청남도  (4400000000)
# 전북특별자치도  (5200000000)
# 전라남도  (4600000000)
# 경상북도  (4700000000)
# 경상남도  (4800000000)
# 제주특별자치도  (5000000000)

# %%
[pop.index[i] for i in range(len(pop))]
# Out:
# ['전국  (1000000000)',
#  '서울특별시  (1100000000)',
#  '부산광역시  (2600000000)',
#  '대구광역시  (2700000000)',
#  '인천광역시  (2800000000)',
#  '광주광역시  (2900000000)',
#  '대전광역시  (3000000000)',
#  '울산광역시  (3100000000)',
#  '세종특별자치시  (3600000000)',
#  '경기도  (4100000000)',
#  '강원특별자치도  (5100000000)',
#  '충청북도  (4300000000)',
#  '충청남도  (4400000000)',
#  '전북특별자치도  (5200000000)',
#  '전라남도  (4600000000)',
#  '경상북도  (4700000000)',
#  '경상남도  (4800000000)',
#  '제주특별자치도  (5000000000)']

# %%
pop.index[0].split()[0]
# Out:
# '전국'

# %%
pop.index = [pop.index[i].split()[0] for i in range(len(pop))]
pop
# Out:
#         2026년02월_총인구수 2026년02월_세대수  2026년02월_세대당 인구 2026년02월_남자 인구수  \
# 전국         51,106,229   24,350,797              210      25,429,357
# 서울특별시       9,304,129    4,512,818              206       4,482,300
# 부산광역시       3,239,016    1,576,653              205       1,574,040
# 대구광역시       2,351,461    1,115,161              211       1,151,654
# 인천광역시       3,054,367    1,404,284              218       1,525,266
# 광주광역시       1,389,235      659,087              211         685,321
# 대전광역시       1,441,405      699,675              206         718,084
# 울산광역시       1,089,835      499,950              218         561,965
# 세종특별자치시       391,240      165,449              236         194,784
# 경기도        13,742,072    6,138,755              224       6,899,712
# 강원특별자치도     1,506,699      769,508              196         757,648
# 충청북도        1,596,816      799,712              200         813,918
# 충청남도        2,136,064    1,064,222              201       1,097,210
# 전북특별자치도     1,721,941      869,571              198         858,094
# 전라남도        1,776,547      913,568              194         897,622
# 경상북도        2,500,499    1,295,998              193       1,265,562
# 경상남도        3,201,389    1,550,713              206       1,614,651
# 제주특별자치도       663,514      315,673              210         331,526
#
#         2026년02월_여자 인구수  2026년02월_남여 비율
# 전국           25,676,872              99
# 서울특별시         4,821,829              93
# 부산광역시         1,664,976              95
# 대구광역시         1,199,807              96
# 인천광역시         1,529,101             100
# 광주광역시           703,914              97
# 대전광역시           723,321              99
# 울산광역시           527,870             106
# 세종특별자치시         196,456              99
# 경기도           6,842,360             101
# 강원특별자치도         749,051             101
# 충청북도            782,898             104
# 충청남도          1,038,854             106
# 전북특별자치도         863,847              99
# 전라남도            878,925             102
# 경상북도          1,234,937             102
# 경상남도          1,586,738             102
# 제주특별자치도         331,988             100

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5,3))
pop1 = pop.sort_values('총인구수')
sns.barplot(x=pop1.index, y='총인구수', data=pop1)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1089/3199263308.py in <cell line: 0>()
#       3
#       4 plt.figure(figsize=(5,3))
# ----> 5 pop1 = pop.sort_values('총인구수')
#       6 sns.barplot(x=pop1.index, y='총인구수', data=pop1)
#       7 plt.xticks(rotation=90)
#
# NameError: name 'pop' is not defined
